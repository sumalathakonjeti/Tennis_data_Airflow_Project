# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plot
import seaborn as sns

# %%
dfusopen=pd.read_csv("/Users/suma/dev/airflow_home/Tennis_data_Airflow_Project/Data/TopUSOpenPlayers.csv")
dfausopen=pd.read_csv("/Users/suma/dev/airflow_home/Tennis_data_Airflow_Project/Data/TopAustralianOpenPlayers.csv")
dffrenchopen=pd.read_csv("/Users/suma/dev/airflow_home/Tennis_data_Airflow_Project/Data/TopFrenchOpenPlayers.csv")
dfwimb=pd.read_csv("/Users/suma/dev/airflow_home/Tennis_data_Airflow_Project/Data/TopWimbledonPlayers.csv")

# %%
from IPython.display import Image
Image(filename = "/Users/suma/dev/airflow_home/Tennis_data_Airflow_Project/Images/Top_wimb.png")

# %%
dfwimb
# Out:
#    Unnamed: 0 tournament          fullname  Count_Win  Count_Lose  total_play  \
# 0         304  Wimbledon     Roger Federer        101          12         113
# 1         268  Wimbledon    Novak Djokovic         72          10          82
# 2         275  Wimbledon    Patrick Rafter         12           2          14
# 3          33  Wimbledon       Andy Murray         57          10          67
# 4         279  Wimbledon      Pete Sampras         11           2          13
# 5         121  Wimbledon  Goran Ivanisevic          9           2          11
# 6         289  Wimbledon      Rafael Nadal         53          12          65
# 7          34  Wimbledon      Andy Roddick         41          12          53
# 8          16  Wimbledon    Alexander Popp         13           4          17
# 9          23  Wimbledon      Andre Agassi         16           5          21
#
#    perc_win
# 0     89.38
# 1     87.80
# 2     85.71
# 3     85.07
# 4     84.62
# 5     81.82
# 6     81.54
# ...

# %%
from IPython.display import Image
Image(filename = "/Users/suma/dev/airflow_home/Tennis_data_Airflow_Project/Images/Top_Aus.png")

# %%
dfausopen
# Out:
#    Unnamed: 0       tournament        fullname  Count_Win  Count_Lose  \
# 0          26  Australian Open    Andre Agassi         30           2
# 1         277  Australian Open  Novak Djokovic         67           8
# 2         320  Australian Open   Roger Federer         97          14
# 3         287  Australian Open  Patrick Rafter          5           1
# 4         303  Australian Open    Rafael Nadal         61          13
# 5         228  Australian Open     Marat Safin         29           7
# 6         226  Australian Open   Magnus Norman          8           2
# 7          40  Australian Open     Andy Murray         48          13
# 8         292  Australian Open    Pete Sampras         11           3
# 9          41  Australian Open    Andy Roddick         38          11
#
#    total_play  perc_win
# 0          32     93.75
# 1          75     89.33
# 2         111     87.39
# 3           6     83.33
# 4          74     82.43
# 5          36     80.56
# ...

# %%
from IPython.display import Image
Image(filename = "/Users/suma/dev/airflow_home/Tennis_data_Airflow_Project/Images/Top_US.png")

# %%
dfusopen
# Out:
#    Unnamed: 0 tournament               fullname  Count_Win  Count_Lose  \
# 0         287    US Open           Pete Sampras         19           2
# 1         276    US Open         Novak Djokovic         72          11
# 2         316    US Open          Roger Federer         89          14
# 3         299    US Open           Rafael Nadal         64          11
# 4          27    US Open           Andre Agassi         28           7
# 5         203    US Open  Juan Martin Del Potro         35           9
# 6          40    US Open            Andy Murray         45          12
# 7         242    US Open            Marin Cilic         36          10
# 8          41    US Open           Andy Roddick         43          12
# 9         224    US Open         Lleyton Hewitt         45          13
#
#    total_play  perc_win
# 0          21     90.48
# 1          83     86.75
# 2         103     86.41
# 3          75     85.33
# 4          35     80.00
# 5          44     79.55
# ...

# %%
from IPython.display import Image
Image(filename = "/Users/suma/dev/airflow_home/Tennis_data_Airflow_Project/Images/Top_French.png")

# %%
dffrenchopen
# Out:
#    Unnamed: 0   tournament             fullname  Count_Win  Count_Lose  \
# 0         313  French Open         Rafael Nadal         93           2
# 1         285  French Open       Novak Djokovic         68          14
# 2         135  French Open      Gustavo Kuerten         24           5
# 3         325  French Open        Roger Federer         70          16
# 4          86  French Open        Dominic Thiem         24           6
# 5          37  French Open          Andy Murray         39          10
# 6           5  French Open         Albert Costa         18           5
# 7          14  French Open        Alex Corretja         17           5
# 8         199  French Open      Karen Khachanov         10           3
# 9         186  French Open  Juan Carlos Ferrero         34          11
#
#    total_play  perc_win
# 0          95     97.89
# 1          82     82.93
# 2          29     82.76
# 3          86     81.40
# 4          30     80.00
# 5          49     79.59
# ...
